# %%
import json
import random
import sys
import time
from pprint import pprint

import requests

sys.path.append("..")
from bohour.poem_samples_large import samples


random.seed(1)

qasaed = [random.choice(samples) for _ in range(10)]

# %%
for i, qaseeda in enumerate(samples):
    pprint(qaseeda)
    payload = ""
    for bait in qaseeda:
        payload += "\n".join(bait.split("#"))
        payload += "\n"
    print("*" * 80)
    print(payload)
    print("*" * 80)
    response = requests.post(
        "http://34.123.169.118:8000/api/analyze",
        data={"baits": payload},
    )
    time.sleep(5)
    if response.ok:
        pprint(response.json())
    else:
        print(i)
        raise('error')
# Out:
# ['إني حلمتُ بعبقريٍّ ناقـدٍ # شعري برغم شموخه الممتـدِّ',
#  'مَنْ يستجيب إلى دراسة حالتي # في الشعرِ ينقلني لأنصع عهـدِ؟',
#  'يمضي يُفَصْفِصُهُ ويرمي عظمَهُ، # واللحمَ يغذو منـه بطنَ الجُنْـدِ؟',
#  'في كــل أيامي حلُمْتُ بماجـدٍ # علاّمـةٍ مُسْتخـرِجٍ لي مجــدي']
# ********************************************************************************
# إني حلمتُ بعبقريٍّ ناقـدٍ
#  شعري برغم شموخه الممتـدِّ
# مَنْ يستجيب إلى دراسة حالتي
#  في الشعرِ ينقلني لأنصع عهـدِ؟
# يمضي يُفَصْفِصُهُ ويرمي عظمَهُ،
#  واللحمَ يغذو منـه بطنَ الجُنْـدِ؟
# في كــل أيامي حلُمْتُ بماجـدٍ
#  علاّمـةٍ مُسْتخـرِجٍ لي مجــدي
#
# ********************************************************************************
# {'arudi_style': [['إنني حلمت بعبقري ناقدي', '1010110111011010110'],
#                  ['شعري برغم شموخهلممتددي', '10101101110110101010'],
#                  ['من يستجيب إلى درراسة حالتي', '1010110111010101110110'],
#                  ['فششعر ينقلنلأنصع عه', '10101101110101110'],
# ...

# %%
samples[7]
# Out:
# ['عاصف باده الرّبى و دخان # أين منك الشّقيق و الأقحوان',
#  'أين منك الرّبيع ينفح بالعطر # و أين السّلاف و الندمان',
#  'بورك الفرد حين يدمي فؤاد # عبقريّ أو حين تدمي بنان',
#  'محيت أشهر الرّبيع فلا أيّار # من دهرنا و لا نيسان',
#  'لا شقيق النّعمان في غوطة الشام # و لا عطره و لا النعمان',
#  'يعرف الفجر أنّ دمعي أصفى # من نداه و يعرف الريحان',
#  'هبّ ندى الفجر كالدموع صفاء # أين منه البلوى و أين الحنان',
#  'يعرف الطّيب أنّ دمعي أذكى # منه عطرا و تعرف الأردان..',
#  'تعرف الراح أنّ دمعي سلاف # و جفوني كؤوسها و الدّنان',
#  'أنا أبكي للّيل أوحشه البدر # و للقلب هدّه الحرمان',
#  'أنا أبكي للهمّ يأوي إلى القلب # فيقسو على الغريب المكان',
#  'أنا أبكي لكلّ طاغ فما يستر # إلاّ الضراعة الطغيان',
#  'أنا أبكي للعين لا تدرك الحسن # و للحسن فاته الإحسان',
#  'أنا أرثي للمترفين فما يبدع # إلاّ الشّقاء و الأحزان',
#  'و أنا المترف الأنيق و لكن # ترفي صاغ فنّه الرحمن',
#  'أنا أبكي لكلّ قيد فأبكي # لقريضي تغلّه الأوزان',
#  'أدمعي في السّماء أنجمها # الزّهر و في البحر درّه و الجمان',
# ...

# %%
samples[0]
# Out:
# ['إني حلمتُ بعبقريٍّ ناقـدٍ # شعري برغم شموخه الممتـدِّ',
#  'مَنْ يستجيب إلى دراسة حالتي # في الشعرِ ينقلني لأنصع عهـدِ؟',
#  'يمضي يُفَصْفِصُهُ ويرمي عظمَهُ، # واللحمَ يغذو منـه بطنَ الجُنْـدِ؟',
#  'في كــل أيامي حلُمْتُ بماجـدٍ # علاّمـةٍ مُسْتخـرِجٍ لي مجــدي']

# %%
for bait in samples[7]:
    payload = "\n".join(bait.split("#"))
    response = requests.post(
            "http://34.123.169.118:8000/api/analyze",
            data={"baits": payload},
        )
    time.sleep(5)
    if response.ok:
        pass
#         pprint(response.json())
    else:
        print(bait)
# Out:
# *** # كيف أغضي على الهوان لجبّار
# في الدّجى لا تميّز الألوان # ***
# *** # يالها دولة تعاقب فيها
# أنّها في رحابكم ضيفان # ***
# *** # يا أبا طارق تحيّة شعب

# %%
from bohour.arudi_style import get_arudi_style
get_arudi_style(samples[7])
# Out:
# [['عصف ده رربى ان ين نك ششيق ا', '10101010101010101010'],
#  ['أين نك رريع فح طر ين سساف ا', '10101010101010101010'],
#  ['برك رد ين مي اد يي أو ين مي ا', '10101010101010101010'],
#  ['ميت هر رريع لا ييار من نا لا ا', '1010101010101010101010'],
#  ['ليق ننان في طة ام لا ره لا ا', '10101010101010101010'],
#  ['يرف جر نن عي فى من اه رف ا', '101010101010101010'],
#  ['هبب دى جر وع اء ين نه وى ين ا', '10101010101010101010'],
#  ['يرف ططيب نن عي كى نه را رف ا', '10101010101010101010'],
#  ['ترف اح نن عي اف ني ها ددا', '101010101010101010'],
#  ['أنا كي لليل شه در لب ددا', '101010101010101010'],
#  ['أنا كي مم وي لى لب سو لى يب ا', '10101010101010101010'],
#  ['أنا كي لل اغ ما تر اا عة ا', '101010101010101010'],
#  ['أنا كي ين لا رك سن سن ته ا', '101010101010101010'],
#  ['أنا ثي ين ما دع اا ششاء ا', '101010101010101010'],
#  ['و نا رف يق كن في اغ ننم', '1010101010101010'],
#  ['أنا كي لل يد كي ضي للا', '1010101010101010'],
# ...
